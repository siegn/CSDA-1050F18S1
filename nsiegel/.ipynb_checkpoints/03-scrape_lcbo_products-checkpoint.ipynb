# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import urllib.parse
import urllib.request
import xml.etree.ElementTree as ET
import io
from bs4 import BeautifulSoup
import time
import sys
import multiprocessing as mp
import numpy as np

# %%
def scrape_all_info2(idlist):
    fieldlist = ['language', 'itemnumber', 'itemname', 'price', 'productsize', 'isdiscontinued', 'islimited',
                 'am', 'ambonusmiles', 'amexpiration', 'kosher', 
                 'lto', 'ltoexpiration', 'ltoregularprice', 'ltosavings', 
                 'releasedate', 'upcnumber', 'sccnumber', 'vao', 'vaodescription', 'vaoexpiration', 
                 'vqa', 'productquantity', 'producer', 'producingsubregion', 'producingregion', 'producingcountry', 
                 'alcoholpercentage', 'sugarcontent', 'tastingnotes', 'pairings', 
                 'itemdescription', 'liquortype', 'categoryname', 'stocktype', 'subcategoryname',
                 'sellingpackage', 'sweetnessdescriptor', 'winestyle', 'winevarietal', 
                 'stylebody', 'stylebody_fr', 'styleflavour', 'styleflavour_fr']

    productinfo = pd.DataFrame(columns=fieldlist)
    
    #timer/counter
    start_time = int(time.time())
    count = 0
    total = len(idlist)
    
    pool = mp.Pool(mp.cpu_count())
    for id in idlist:
        pool.apply_async(parse_item_xml, args=(str(id),fieldlist), callback =collect_result)
        #print(id)
        # Pull xml from lcbo api
        #xmltest = pullXML(str(id))
        # Extract dict of values
        #newitem = parse_item_xml(xmltest, fieldlist)

        # Add to our dataframe
        #productinfo = productinfo.append(newitem,ignore_index=True)
    pool.close()
    pool.join()
    #print(results)
    return results
        #counter/timer
        #end_time = int(time.time())
        #min_spent = round(((end_time-start_time)/60),2)
        #remaining_time = round((min_spent/max(count,1))*max((total-count),1),2)

        #count_str = 'extracted ' + str(count) + '/' + str(total) + \
        #        ' products in total ' + str(min_spent) + ' minutes' + \
        #        ' estimated time remaining is ' + str(remaining_time) + ' minutes'
        #if count % 100 == 0:
        #    sys.stdout.write("\r{}".format(count_str))
        #count += 1
        
        # sleep so we don't get blacklisted
        #time.sleep(0.5)
        
    #save to parquet, also return the pandas dataframe
    #productinfo.to_parquet("productinfo2.parquet")
    #return productinfo

# %%
def collect_result(result):
    #print('hi')
    global results
    #print('------')
    #print(result)
    results = results.append(result,ignore_index = True)
    #print(results)

# %%
def parse_item_xml(id, fieldlist):
    #print(id)
    #print(fieldlist)
    xmlstring = pullXML(id)
    #print(xmlstring)
    soup = BeautifulSoup(xmlstring)
    product = soup.find('products')
    
    newitem = {}
    #print(fieldlist)
    for field in fieldlist:
        value = product.find(field)
        if value is not None:
            newitem[field] = value.text
    #print(newitem)
    return newitem

# %%
def pullXML(ProductID):
    url = 'http://www.foodanddrink.ca/lcbo-webapp/productdetail.do?itemNumber=' + ProductID
    #print(url)
    user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
    values = {'language' : 'en' }
    headers = { 'User-Agent' : user_agent }
    data = urllib.parse.urlencode(values)
    data = data.encode('ascii')
    req = urllib.request.Request(url, data, headers)
    #print('hi')
    try:
        with urllib.request.urlopen(req) as response:
           content = response.read()
        #print(content)
        return content
        #return BeautifulSoup(content, 'xml')
    except :
        #print(response)
        raise response

# %% [markdown]
# The cell below will pull for all item ranges, using a multiprocess in order to execute faster.
#
# This will take quite a while. It took about 3 days for me.

# %%
fieldlist = ['language', 'itemnumber', 'itemname', 'price', 'productsize', 'isdiscontinued', 'islimited',
                 'am', 'ambonusmiles', 'amexpiration', 'kosher', 
                 'lto', 'ltoexpiration', 'ltoregularprice', 'ltosavings', 
                 'releasedate', 'upcnumber', 'sccnumber', 'vao', 'vaodescription', 'vaoexpiration', 
                 'vqa', 'productquantity', 'producer', 'producingsubregion', 'producingregion', 'producingcountry', 
                 'alcoholpercentage', 'sugarcontent', 'tastingnotes', 'pairings', 
                 'itemdescription', 'liquortype', 'categoryname', 'stocktype', 'subcategoryname',
                 'sellingpackage', 'sweetnessdescriptor', 'winestyle', 'winevarietal', 
                 'stylebody', 'stylebody_fr', 'styleflavour', 'styleflavour_fr']

results = pd.DataFrame(columns=fieldlist)

for i in range(1,111):
    maxrange = i * 10000
    minrange = (i-1) * 10000 + 1
    print('--')
    print(str(minrange) + ' to ' + str(maxrange))
    product_info_current = scrape_all_info2(range(minrange,maxrange)).dropna()
    product_info_current.to_parquet('data/product_info'+str(maxrange)+'.parquet')
# Out:
# --
# 1090001 to 1100000

# %% [markdown]
# Now let's consolidate all the files we've scraped:

# %%
from pathlib import Path
import pandas as pd

data_dir = Path('data/')
full_df = pd.concat(
    pd.read_parquet(parquet_file)
    for parquet_file in data_dir.glob('product_info*.parquet')
)

# %%
full_df = full_df.dropna()

# %% [markdown]
# Fix datatypes:

# %%
full_df.dtypes
# Out:
# language               object
# itemnumber             object
# itemname               object
# price                  object
# productsize            object
# isdiscontinued         object
# islimited              object
# am                     object
# ambonusmiles           object
# amexpiration           object
# kosher                 object
# lto                    object
# ltoexpiration          object
# ltoregularprice        object
# ltosavings             object
# releasedate            object
# upcnumber              object
# sccnumber              object
# vao                    object
# vaodescription         object
# vaoexpiration          object
# vqa                    object
# productquantity        object
# producer               object
# producingsubregion     object
# producingregion        object
# producingcountry       object
# alcoholpercentage      object
# sugarcontent           object
# tastingnotes           object
# pairings               object
# itemdescription        object
# liquortype             object
# categoryname           object
# stocktype              object
# subcategoryname        object
# sellingpackage         object
# sweetnessdescriptor    object
# winestyle              object
# winevarietal           object
# stylebody              object
# stylebody_fr           object
# styleflavour           object
# styleflavour_fr        object
# dtype: object

# %%
full_df=pd.read_parquet('data/productinfo_combined.parquet')

# TODO: a lot of these are just patterns that repeat so could be made into functions, 
#or ideally loop through all columns in one go.
pd.options.mode.chained_assignment = None
full_df['language']            = full_df['language'].astype('str')
full_df['itemnumber']          = full_df['itemnumber'].astype(int)
full_df['itemname']            = full_df['itemname'].astype('str')

# Strip the $ From price
full_df['price']               = full_df['price'].str.replace('$', '', case=False, regex=False).astype(float)
                                                    
# Strip productsize into quantity, volume and remove ml
full_df['quantity']            = (full_df['productsize'].replace('N/A', None)
                                                        .str.extract('(^.*)(?=x)')
                                                        .replace(np.nan,'1')
                                                        .astype(int)
                                 )

full_df['productsize']          = (full_df['productsize'].replace('(^.*x)','',regex=True)
                                                          .str.extract('(\d*)')
                                                          .replace('',None,regex=False)
                                                          .astype(int)
                                  )

full_df['isdiscontinued']      = full_df['isdiscontinued'].astype(bool)
full_df['islimited']           = full_df['islimited'].astype(bool)

# Convert N to False and Y to True
full_df['am']                  = full_df['am'] == 'Y'

full_df['ambonusmiles']        = full_df['ambonusmiles'].replace('','0',regex=False).astype(int)
full_df['amexpiration']        = pd.to_datetime(full_df.amexpiration.replace("N/A",'',regex=False))

full_df['kosher']              = full_df['kosher'] == 'Y'
full_df['lto']                 = full_df['lto'] == 'Y'

full_df['ltoexpiration']       = pd.to_datetime(full_df.ltoexpiration.replace("N/A",'',regex=False))
full_df['ltoregularprice']     = full_df['ltoregularprice'].str.replace('$', '', case=False, regex=False).astype(float)
full_df['ltosavings']          = full_df['ltosavings'].str.replace('$', '', case=False, regex=False).astype(float)

full_df['releasedate']         = pd.to_datetime(full_df.releasedate.replace("N/A",'',regex=False))

full_df['upcnumber']           = full_df['upcnumber'].astype(int)
full_df['sccnumber']           = full_df['sccnumber'].astype(int)

full_df['vao']                 = full_df['vao'] == 'Y'
full_df['vaodescription']      = full_df['vaodescription'].astype('str')
full_df['vaoexpiration']       = pd.to_datetime(full_df.vaoexpiration.replace("N/A",'',regex=False))

full_df['vqa']                 = full_df['vqa'] == 'Y'
full_df['productquantity']     = full_df['productquantity'].astype(int)

full_df['producer']            = full_df['producer'].astype(str)
full_df['producingsubregion']  = full_df['producingsubregion'].astype(str)
full_df['producingregion']     = full_df['producingregion'].astype(str)
full_df['producingcountry']    = full_df['producingcountry'].astype(str)

full_df['alcoholpercentage']   = (full_df['alcoholpercentage'].replace('\%', '', regex=True)
                                                              .replace("N/A",'',regex=False)
                                                              .replace('','0', regex=False)
                                                              .astype(float)
                                 )

full_df['sugarcontent']        = full_df['sugarcontent'].str.extract('(\d*)')
full_df['tastingnotes']        = full_df['tastingnotes'].astype(str)
full_df['pairings']            = full_df['pairings'].astype(str)
full_df['itemdescription']     = full_df['itemdescription'].astype(str)
full_df['liquortype']          = full_df['liquortype'].astype(str)
full_df['categoryname']        = full_df['categoryname'].astype(str)
full_df['stocktype']           = full_df['stocktype'].astype(str)
full_df['subcategoryname']     = full_df['subcategoryname'].astype(str)
full_df['sellingpackage']      = full_df['sellingpackage'].astype(str)
full_df['sweetnessdescriptor'] = full_df['sweetnessdescriptor'].astype(str)
full_df['winestyle']           = full_df['winestyle'].astype(str)
full_df['winevarietal']        = full_df['winevarietal'].astype(str)
full_df['stylebody']           = full_df['stylebody'].astype(str)
full_df['stylebody_fr']        = full_df['stylebody_fr'].astype(str)
full_df['styleflavour']        = full_df['styleflavour'].astype(str)
full_df['styleflavour_fr']     = full_df['styleflavour_fr'].astype(str)

# %%
full_df.to_parquet('data/lcbo_productinfo.parquet')

# %% [markdown]
# And let's take a look at the distribution of product codes:

# %%
full_df.dtypes
# Out:
# language                       object
# itemnumber                      int64
# itemname                       object
# price                         float64
# productsize                     int64
# isdiscontinued                   bool
# islimited                        bool
# am                               bool
# ambonusmiles                    int64
# amexpiration           datetime64[ns]
# kosher                           bool
# lto                              bool
# ltoexpiration          datetime64[ns]
# ltoregularprice               float64
# ltosavings                    float64
# releasedate            datetime64[ns]
# upcnumber                       int64
# sccnumber                       int64
# vao                              bool
# vaodescription                 object
# vaoexpiration          datetime64[ns]
# vqa                              bool
# productquantity                 int64
# producer                       object
# producingsubregion             object
# producingregion                object
# producingcountry               object
# alcoholpercentage             float64
# sugarcontent                   object
# tastingnotes                   object
# pairings                       object
# itemdescription                object
# liquortype                     object
# categoryname                   object
# stocktype                      object
# subcategoryname                object
# sellingpackage                 object
# sweetnessdescriptor            object
# winestyle                      object
# winevarietal                   object
# stylebody                      object
# stylebody_fr                   object
# styleflavour                   object
# styleflavour_fr                object
# quantity                        int64
# dtype: object

# %% [markdown]
# See what unique values are in each column

# %%
[print(column, full_df[column].unique()) for column in full_df.columns]
# Out:
# language ['en']
# itemnumber [130047 130138 130195 ...  29090  29280  29579]
# itemname ['KRONE CUVÉE BRUT ROSÉ SPARKLING 2017' 'MEIOMI PINOT NOIR'
#  '13TH STREET SANDSTONE VINEYARD GAMAY NOIR 2014' ...
#  'CIAO SANGIOVESE ORGANIC TERRA DE CHIETI IGP'
#  'TERRAZAS DE LOS ANDES RESERVA MALBEC 2016' 'CULMEN RESERVA 2011']
# price [ 19.95  21.95  24.25 ... 194.   108.95 635.  ]
# productsize [  750   500  1140   473   150  1500  1750   700   330   720   375   341
#   1000   355   180   200   250   290   600   480   300  1800  3000   710
#    440   275  4000   100    20  1180   450    50  4500   400   650   550
#    360   458  3100   296   660 30000   350   236  2000   625   740   460
#   6000   900   125    30   680     1   946  1890   284   270  5000   568
#  50000  3500   565   187   781]
# isdiscontinued [ True]
# islimited [ True]
# am [False  True]
# ambonusmiles [ 0 20  3  6  5 15 18  4 10  8 25  1 30  9 23]
# amexpiration [                          'NaT' '2019-07-20T00:00:00.000000000']
# kosher [False  True]
# lto [False  True]
# ltoexpiration [                          'NaT' '2019-07-21T00:00:00.000000000']
# ltoregularprice [ 0.   12.95 12.   28.55  3.25 10.   19.95 37.   17.45 13.45 28.2  15.95
#  17.95 34.2  28.05 14.95 49.95 11.   15.   69.95 12.5  62.5  42.45 41.95
#  45.95 44.35 42.95 13.95 25.95 42.6  16.   41.9  15.05 34.95  2.45 79.95
#  14.45  2.95 13.5  25.   17.   29.95 32.2   3.1  18.   18.95 15.5  14.9
#  63.1  30.45 11.5   3.55 57.95 11.45  3.45  3.3   2.9  45.35 44.95 10.95
#  31.55 63.25 20.1  14.   34.35  9.95 35.95 15.45 11.95 28.95 39.95 29.45
#  57.   28.45 12.75 55.2  90.2   2.15 33.95 16.25 22.   10.45 63.95 16.95
#  14.85 59.95  3.5  30.7   4.25  4.65 29.   18.25 26.95 10.75 40.95 14.6
#   4.   80.2  22.45  2.85  3.15 35.45 64.5   9.   30.4  29.7  14.55 21.95
#   3.35  2.25 99.7  81.95 62.15 12.45 11.05 22.95 24.95]
# ltosavings [ 0.    2.    1.35  0.2   1.    4.    1.5   3.    5.    2.5   1.25  0.25
#   1.55  1.95  0.45  0.55  0.3   6.    2.8   0.4   0.15  1.75  1.2  10.  ]
# releasedate ['2018-09-29T00:00:00.000000000' '2019-04-03T00:00:00.000000000'
#  '2017-11-11T00:00:00.000000000' '2017-10-14T00:00:00.000000000'
#                            'NaT' '2019-05-11T00:00:00.000000000'
#  '2018-11-10T00:00:00.000000000' '2018-11-24T00:00:00.000000000'
#  '2019-03-25T00:00:00.000000000' '2018-12-22T00:00:00.000000000'
#  '2017-04-15T00:00:00.000000000' '2019-02-16T00:00:00.000000000'
#  '2018-12-08T00:00:00.000000000' '2018-10-13T00:00:00.000000000'
#  '2018-02-03T00:00:00.000000000' '2019-01-19T00:00:00.000000000'
#  '2019-07-06T00:00:00.000000000' '2019-06-08T00:00:00.000000000'
#  '2019-03-16T00:00:00.000000000' '2018-08-04T00:00:00.000000000'
#  '2019-06-22T00:00:00.000000000' '2018-09-01T00:00:00.000000000'
#  '2019-07-20T00:00:00.000000000' '2019-04-25T00:00:00.000000000'
#  '2019-05-02T00:00:00.000000000' '2019-03-02T00:00:00.000000000'
#  '2018-12-06T00:00:00.000000000' '2019-02-02T00:00:00.000000000'
#  '2019-03-30T00:00:00.000000000' '2019-01-05T00:00:00.000000000'
#  '2000-11-30T00:00:00.000000000' '2016-03-05T00:00:00.000000000'
#  '2018-09-15T00:00:00.000000000' '2018-10-27T00:00:00.000000000'
#  '2018-03-03T00:00:00.000000000' '2011-01-08T00:00:00.000000000'
#  '2019-04-27T00:00:00.000000000' '2018-07-20T00:00:00.000000000'
#  '2019-02-07T00:00:00.000000000' '2015-10-17T00:00:00.000000000'
#  '2014-02-01T00:00:00.000000000' '2018-10-04T00:00:00.000000000'
#  '2013-10-12T00:00:00.000000000' '2019-06-06T00:00:00.000000000'
#  '2018-08-18T00:00:00.000000000' '2019-04-13T00:00:00.000000000'
#  '2018-12-21T00:00:00.000000000' '2017-11-25T00:00:00.000000000'
#  '2019-04-04T00:00:00.000000000' '2018-09-06T00:00:00.000000000'
#  '2019-07-19T00:00:00.000000000' '2018-05-03T00:00:00.000000000'
#  '2019-05-25T00:00:00.000000000' '2015-05-02T00:00:00.000000000'
#  '2018-07-07T00:00:00.000000000' '2018-10-16T00:00:00.000000000'
#  '2014-08-02T00:00:00.000000000' '2012-07-25T00:00:00.000000000'
#  '2012-03-17T00:00:00.000000000' '2018-07-18T00:00:00.000000000'
#  '2018-06-09T00:00:00.000000000' '2019-02-21T00:00:00.000000000'
#  '2017-07-22T00:00:00.000000000' '2018-07-21T00:00:00.000000000'
#  '2018-06-23T00:00:00.000000000' '2015-12-12T00:00:00.000000000'
#  '2018-03-31T00:00:00.000000000' '2018-11-01T00:00:00.000000000'
#  '2019-03-07T00:00:00.000000000' '2018-01-20T00:00:00.000000000'
#  '2014-02-15T00:00:00.000000000' '2017-10-05T00:00:00.000000000'
#  '2016-09-03T00:00:00.000000000' '2018-02-15T00:00:00.000000000'
#  '2016-08-20T00:00:00.000000000' '2016-11-17T00:00:00.000000000'
#  '2016-10-01T00:00:00.000000000' '2016-10-06T00:00:00.000000000'
#  '2017-09-11T00:00:00.000000000' '2017-05-27T00:00:00.000000000'
#  '2018-08-27T00:00:00.000000000' '2017-02-18T00:00:00.000000000'
#  '2018-01-06T00:00:00.000000000' '2017-04-01T00:00:00.000000000'
#  '2017-04-06T00:00:00.000000000' '2017-08-05T00:00:00.000000000'
#  '2017-02-16T00:00:00.000000000' '2017-06-26T00:00:00.000000000'
#  '2017-10-12T00:00:00.000000000' '2004-01-17T00:00:00.000000000'
#  '2015-08-22T00:00:00.000000000' '2019-04-24T00:00:00.000000000'
#  '2015-10-31T00:00:00.000000000' '2019-03-28T00:00:00.000000000'
#  '2018-11-22T00:00:00.000000000' '2017-11-07T00:00:00.000000000'
#  '2017-10-11T00:00:00.000000000' '2017-11-16T00:00:00.000000000'
#  '2018-02-07T00:00:00.000000000' '2010-10-30T00:00:00.000000000'
#  '2018-03-29T00:00:00.000000000' '2009-05-02T00:00:00.000000000'
#  '2018-06-28T00:00:00.000000000' '2018-01-18T00:00:00.000000000'
#  '2015-05-15T00:00:00.000000000' '2013-03-16T00:00:00.000000000'
#  '2018-05-05T00:00:00.000000000' '2019-05-05T00:00:00.000000000'
#  '2009-01-10T00:00:00.000000000' '2014-01-04T00:00:00.000000000'
#  '2016-04-30T00:00:00.000000000' '2019-04-18T00:00:00.000000000'
#  '2014-09-13T00:00:00.000000000' '2008-07-05T00:00:00.000000000'
#  '2009-08-28T00:00:00.000000000' '2010-11-27T00:00:00.000000000'
#  '2018-03-07T00:00:00.000000000' '2018-10-18T00:00:00.000000000'
#  '2010-01-23T00:00:00.000000000' '2011-08-06T00:00:00.000000000'
#  '2015-05-30T00:00:00.000000000' '2018-11-29T00:00:00.000000000'
#  '2012-01-21T00:00:00.000000000' '2016-08-06T00:00:00.000000000'
#  '2012-04-28T00:00:00.000000000' '2009-08-29T00:00:00.000000000'
#  '2016-11-07T00:00:00.000000000' '2019-02-14T00:00:00.000000000'
#  '2019-05-15T00:00:00.000000000' '2014-11-08T00:00:00.000000000'
#  '2018-11-15T00:00:00.000000000' '2012-09-29T00:00:00.000000000']
# upcnumber [6005176000193  855165005076  895770009458 ... 8033116400138 7790975001487
#  8413472059438]
# sccnumber [16005176000190 20855165005070 10895770009455 ... 18033116400074
#  17790975194773 28413472059432]
# vao [False  True]
# vaodescription ['' 'Retro cork coaster' 'Sobieski 50mL VA' "JP Wiser's Deluxe 50ml x 2"
#  'Prince Igor Extreme 50ml' 'Canadian Club 100% Rye 2 x 50ml'
#  "JP Wiser's Deluxe 50ml" 'Captain Morgan Original Spiced 50ml' 'Reamer'
#  'Canadian Club Premium 2 x 50m' 'Jim Beam Apple 2 x 50ml' 'Summer Sleeve'
#  'Bushmills Original 50ml' "Lamb's Palm Breeze 50ml"
#  'Canada Flag Luggage Tag' 'Banff Ice 50ml' '50ml Amaro Lucano'
#  'Walter Caesar Mix 946ml' 'Made for Canada Value Add' 'Ciroc 50ml'
#  'orty Creek BBQ Sauce and BBQ Scraper.' 'Stemless Glass'
#  "Mott's 50th Cooler Bag" 'Coors Banquet Koozie'
#  'Diplomatico Exclusiva 50 mL' 'BBQ Spice Rub' 'Bluetooth Earbuds'
#  '50 mL Fireball Whisky' '50ml LVA' 'Snapple Koozie' 'Compliment Envelope'
#  'Stemless Patio Glass' 'Jim Beam Apple 50ml' 'Extreme Bean'
#  'Georgian Bay Recipe Booklet' 'Mini Bottle Value add'
#  '1 x Bushmills Black Bush 50ml'
#  'Moet & Chandon Imp Brut 150th Anniversary Bot'
#  '2x Bushmills Black Bush 50ml' 'Rose shaped reusable wine bag' 'Value Ad'
#  "JP Wiser's Old Fashioned 50ml x 2" 'Polar Ice Vodka 50ml'
#  'Stalk & Barrel Red Blend 50ml' 'Branded cork coaster'
#  'Sticker Coupon for a TBD item' 'Limoncello 50ml'
#  '1 x Bushmills Original (rep applied)' 'Luxardo Mini Liqueur'
#  'Phone grip' 'Mule Cup' 'The Kraken 50ml' '50ml Bacardi 4 YO'
#  '2x50ml Bacardi Gold' 'Coaster' 'Spanish Spices' 'Beatties Potato Vodka'
#  'Jigger' 'Glass' 'Summer Party Value Add' 'Branded Glassware'
#  'Forty Creek BBQ Sauce and BBQ Scraper.'
#  'Ritter Sport Mini Chocolate 16.67g' 'FB Seasonal Label Magnet' 'Opener'
#  'Caesar Rimmers' 'Made for Canada Wine Glasses' 'Wireless Ear Buds'
#  'Wireless Earbuds' 'Canada Day ON Bags' 'Jerky' "Lamb's White Rum 50ml"
#  'Forty Creek BBQ Sauce and BBQ Scraper' 'Mini Pineapple Floatie'
#  '1 x 50 ml Gibsons Finest' "Lamb's White Rum 50ml x 2"
#  "Walter's Spice Rimmer" 'Bushmills Black Bush 50ml' 'Blue Nun Pen']
# vaoexpiration [                          'NaT' '2019-07-20T00:00:00.000000000']
# vqa [False  True]
# productquantity [   8 7160    1 ... 7543 3614 4536]
# producer ['Vinimark Trading' 'Constellation Brands Inc. (Us)'
#  'Thirteenth Street Wine Corp.' ... 'Casa Dos Vinhos Da Madeira Lda.'
#  'Bodegas Chandon S.A.' 'Bodegas Lan']
# producingsubregion ['' 'Four Mile Creek' 'Niagara Peninsula' 'Lincoln Lakeshore'
#  'Niagara-on-the-Lake' 'Northern Rhône' 'Niagara Escarpment'
#  'Twenty Mile Bench' 'Okanagan Valley' 'Sub-Region Not Specified'
#  'Mendocino' 'Luján de Cuyo' 'Lodi' 'Napa Valley' 'Saint-Estèphe'
#  'Barbaresco' 'Bordeaux Supérieur' 'Sancerre' 'Uco Valley' 'Vouvray'
#  'Coonawarra' 'Southern Rhône' 'Champagne' 'Chablis'
#  'Prince Edward County' 'Creek Shores' 'Barossa Valley' 'Corbières'
#  'Niagara River' 'Brunello di Montalcino' 'Sonoma County'
#  'Monterey County' 'Bourgogne' 'Russian River Valley' 'Valpolicella'
#  'Willamette Valley' 'Tupungato' 'Paso Robles' 'Lake Erie North Shore'
#  'Collio' 'Barossa' 'Barolo' 'Côtes du Roussillon'
#  'Côtes de Bordeaux -- Castillon' 'Taurasi' 'Bolgheri' 'Rioja Alta'
#  'Chianti Classico' 'Beamsville Bench' 'Côte de Beaune'
#  'Vino Nobile de Montepulciano' 'Crémant de Bourgogne' 'Sonoma Mountain'
#  'Padthaway' 'Speyside' 'Pauillac' 'Vinemount Ridge' 'Sonoma Coast'
#  'Margaux' 'Saint-Julien' 'Saint-Émilion' 'Sauternes' 'Sonoma Valley'
#  'Islay' 'Madiran' 'Columbia Valley' 'Highland' 'Santa Lucia Highlands'
#  'Santa Barbara' 'McLaren Vale' "Barbera d'Alba" 'Montagne-Saint-Émilion'
#  'Pessac-Léognan' 'Margaret River' "Coteaux d'Aix-en-Provence"
#  'Clare Valley' 'Ontario' 'North Coast' 'San Rafael' 'Central Coast'
#  'Haut-Médoc' 'Frankland River' 'Prosecco' "Barbera d'Asti" 'Montalcino'
#  'Short Hills Bench, Niagara Peninsula' "Montepulciano d'Abruzzo"
#  'Adelaide Hills' 'Walla Walla Valley' 'Cahors' 'Côtes de Provence'
#  'Yarra Valley' 'Côte de Nuits' 'Nemea' "St. David's Bench" 'Chianti'
#  'Pyrenees' 'Lake County' 'Côte Chalonnaise' 'Mâconnais'
#  'Côtes de Bordeaux -- Blaye' 'Côtes de Bordeaux' 'Cortona'
#  'Santa Ynez Valley' 'Côtes de Bordeaux -- Cadillac' 'Pomerol'
#  'Montefalco Sagrantino' 'Amarone' 'Eden Valley' 'Maremma'
#  'Niagara Lakeshore' 'Côtes de Bourg' 'Hunter Valley' 'Langhorne Creek'
#  'Médoc' 'Bordeaux' 'Santa Rita Hills' 'Langhe' 'Santa Maria Valley'
#  'Carneros' 'Monferrato' 'Pouilly-Fumé' 'Saumur' "Côte d'Or" 'Marsala'
#  'Grave del Friuli' 'Touraine' 'Languedoc' 'Douro Superior'
#  'Lalande-de-Pomerol' 'Pessac-Léognan/Graves' 'Muscadet Sèvre et Maine'
#  'Geelong' 'Treviso' 'Chianti Rufina' 'Fitou' 'Fleurieu'
#  'Santa Cruz Mountains' 'Coteaux du Languedoc' 'Sauternes/Barsac'
#  'Coteaux du Layon' 'Calchaquí Valley' 'Aglianico del Vulture' 'Etna'
#  'Minervois' 'Maury' 'Graves' 'Lowland' 'Wrattonbully'
#  'Côtes de Bordeaux -- Francs' 'Soave' 'Gimblett Gravels'
#  'Colli Orientali del Friuli' "Dolcetto d'Alba" 'Fraser Valley'
#  'Sangiovese di Romagna' 'Lussac-Saint-Émilion' 'Orange' 'South Islands'
#  'Alto Agrelo' 'Bandol' 'Moulis' 'Saumur Champigny' 'Amador County'
#  'Bolgheri Superiore' 'Vesuvio' 'Heathcote' 'Fronsac' 'Savennières'
#  'Valdadige']
# producingregion ['Western Cape' 'California' 'Ontario' 'Region Not Specified' 'Rhône'
#  'Abruzzo' 'Belgium' 'Mendoza' 'Ribera del Duero' 'Terra Alta'
#  'British Columbia' 'Veneto' 'Piedmont' 'Rueda' 'Quebec' 'Bordeaux'
#  'Rioja' 'Bairrada' 'Victoria' 'New Brunswick' 'Loire' 'Alsace'
#  'Vinho Verde' 'Galilee' 'Ukraine' 'South Australia' 'Kakheti'
#  'South of France' 'Sicily' 'Aconcagua Valley' 'Colchagua Valley'
#  'Scotland' 'Leyda Valley' 'Muntenia' 'Puglia' 'Limari Valley' 'Champagne'
#  'Cognac' 'Burgundy' 'Tuscany' 'San Antonio Valley' 'Alentejo' 'Douro'
#  'Marlborough' 'Roussillon' 'Midi' 'Gisborne' "Hawke's Bay" 'Friuli'
#  'Portugal' 'Bierzo' 'Languedoc' 'New York' 'Paarl' 'Central Valley'
#  'Judean Hills' 'Galilee Heights' 'Umbria' 'Oregon' 'Rheinhessen'
#  'Tasmania' 'San Juan' 'Baden' 'Cariñena' 'Jumilla' 'Peumo' 'Japan'
#  'Peloponnese' 'La Mancha' 'Nova Scotia' 'Robertson' 'Campania' 'Marche'
#  'Croatia' 'Lazio' 'Alto Adige' 'Rapel Valley' 'Emilia-Romagna'
#  'Central Otago' 'Kentucky' 'Penedès' 'Wisconsin' 'England' 'Jerez'
#  'Estonia' 'Swartland' 'Castilla y León' 'Santorini' 'Mosel' 'Drama'
#  'Rhine' 'Poland' 'Venezie' 'Southwest' 'Is. Of Samos' 'Washington'
#  'Crete' 'Sardinia' 'Maule Valley' 'Tennessee' 'New Jersey' 'Israel'
#  'Toro' 'Dão' 'Lombardy' 'Stellenbosch' 'Western Australia' 'Provence'
#  'Niederösterreich' 'Wien' 'Méntrida' 'N/A' 'Südtirol/Alto Adige'
#  'Macedonia' 'Newfoundland' 'Pfalz' 'Ribeira Sacra' 'Rias Baixas'
#  'Casablanca Valley' 'Minnesota' 'Montsant' 'Maine' 'Netherlands' 'Sweden'
#  'Almansa' 'Priorat' 'Savoie' 'Bulgaria' 'Campo de Borja' 'Yecla'
#  'Beaujolais' 'Armagnac' 'Greece' 'Calvados' 'Alto Adige/Trentino'
#  'New Zealand' 'Cape Point' 'Setubal' 'Walker Bay' 'Franschhoek'
#  'Patagonia' 'Kremstal' 'Manitoba' 'Kamptal' 'Trentino' 'Catalunya'
#  'Coastal Region' "Valle d'Aosta" 'Pirque' 'Jamaica' 'Georgia' 'Tarragona'
#  'Illinois' 'Germany' 'Valencia' 'Samson' 'Hungary' 'Liguria'
#  'Maipo Valley' 'Curicó Valley' 'Montilla-Moriles' 'Austria'
#  'New South Wales' 'Nemea' 'Lontué Valley' 'India' 'Salta' 'Ireland'
#  'Thracian Valley' 'Lolol Valley' 'Virginia' 'Jura' 'Texas'
#  'Cafayate Valley' 'Tupungato' 'Molise' 'Lugana' 'Bullas' 'Massachusetts'
#  'Latvia' 'Styria' 'Penedes' 'Cederberg' 'Madeira' 'Prince Edward Island'
#  'Thessalia' 'Agioritiko' 'Central Greece' 'Pennsylvania'
#  'Baja California' 'Finland' 'Luxembourg' 'Madrid' 'Szekszárd'
#  'Basilicata' 'Península de Setúbal' 'Lisboa' 'Beiras' 'Italy'
#  'Switzerland' 'Calabria' 'Slovakia' 'France' 'Alicante' 'Nelson' 'Kosovo'
#  'Limnos' 'Wairarapa' 'Simonsberg-Stellenbosch' 'China' 'Corsica'
#  'Calatayud' 'Thracian Lowlands' 'Rheingau' 'Waipara' 'Achaia'
#  'Cachapoal Valley' 'Bekaa Valley' 'Costers del Segre' 'Mallorca'
#  'Coastal' 'Valdepenas' 'Alenquer' 'Aconcagua Costa' 'Weinviertel'
#  'Martinborough' 'Wales' 'Vermont' 'Cahors' 'Navarra' 'Canberra District'
#  'Calchaquí Valley' 'South Belgium (Hainut)' 'Traisental' 'Auckland'
#  'Michigan' 'Wachau' 'Denmark' 'Hawaii' 'North Carolina' 'Alberta'
#  'Utiel-Requena' 'Elgin' 'Darling' 'Spain' 'South Africa' 'Nahe' 'Málaga'
#  'Connecticut' 'Turkey' 'Moldova' 'Peru' 'South Korea' 'Guyana'
#  'Canelones' 'Uruguay' 'Milwaukee' 'Burgenland' 'South West' 'Samos'
#  'Mosel-Saar-Ruwer' 'Argentina' 'Constantia' 'Baden & Wurttemberg'
#  'Bolivia' 'Aragón' 'Elquí Valley' 'Armenia' 'Moldavia' 'Bermuda' 'Ohio']
# producingcountry ['South Africa' 'USA' 'Canada' 'Denmark' 'France' 'United Kingdom' 'Italy'
#  'Belgium' 'Argentina' 'Spain' 'Caribbean' 'Ireland' 'Greece' 'Barbados'
#  'Sri Lanka' 'Russia' 'Japan' 'Portugal' 'Australia' 'Hungary' 'Israel'
#  'Ukraine' 'Georgia' 'Mexico' 'Chile' 'Romania' 'New Zealand'
#  'Czech Republic' 'Germany' 'Nicaragua' 'Panama' 'China' 'Croatia'
#  'Jamaica' 'Puerto Rico' 'India' 'Finland' 'Poland' 'Guyana' 'Colombia'
#  'Estonia' 'Austria' 'Sweden' 'Netherlands' 'Cuba' 'Latvia'
#  'Dominican Republic' 'Trinidad and Tobago' 'South Korea' 'Bulgaria'
#  'Guatemala' 'Philippines' 'Lebanon' 'Switzerland' 'Venezuela' 'Bermuda'
#  'Luxembourg' 'Slovakia' 'Kosovo' 'Republic of North Macedonia'
#  'Republic of Moldova' 'Slovenia' 'Thailand' 'Saint Lucia' 'Armenia'
#  'Iceland' 'Brazil' 'Peru' 'Singapore' 'Turkey' 'Montenegro' 'Serbia'
#  'Vietnam' 'Norway' 'Uruguay' 'Cyprus']
# alcoholpercentage [12.5  14.5  13.    4.5  13.5  11.9   0.   12.   40.    5.    6.   13.9
#  46.   12.8  11.1  14.   24.   14.7  28.   30.   42.    8.8  13.4  11.5
#  15.5   4.   11.8   4.6   5.1   5.5   9.    4.9  12.2   4.4  13.3   4.8
#  15.9  14.1  43.   15.    6.3   3.5  14.8  15.2  45.8  11.3  14.6  11.
#  12.7  10.5  11.2  20.   13.2   7.   45.   23.    6.5   3.    8.   22.5
#  16.6  14.3   9.5  18.   35.   12.3  10.    4.7  11.4   5.2  52.   11.6
#  36.   16.3   8.5  16.   11.7  15.1  42.8  42.6  40.2   5.3  13.8  17.
#  '151' '73' '131' '59' '53' '34' '200' '236' '43' '188' '103' '198' '212'
#  '209' '90' '55' '77' '82' '366' '307' '387' '155' '62' '97' '113' '248'
#  '30' '202' '180' '57' '61' '274' '100' '199' '110' '245' '204' '176'
#  '265' '191' '221' '263' '210' '102' '309' '237' '126' '218' '119']
# tastingnotes ["'Méthode Cap Classique' is South African shorthand for the very same time-tested traditional method used to make Champagne. An incredible value, this pink example blends 85% Pinot Noir and 15% Chardonnay sourced from a 300-year-old farm. Look for tangy red berry and citrus notes, and sip with crispy duck breast or your favourite early-autumn appetizers."
#  'Bring the drama of the California coast to your next dinner party host without paying a dramatic price. Meomi blends grapes from three top areas for producing world-class, velvety smooth Pinot Noirs.'
#  "Hailing from a single site in Niagara-on-the-Lake planted in 1983, this is a traditionally made gamay fermented open-top, punched down and aged in French oak. So no tooty-fruity gamay here, indeed it is quite elegant, complex and refined. Expect complex subtle aromas of red currant/cherry, fine spice, pepper and some twigginess. It's mid-weight, dry and nicely contained with a fine red fruit and spice finish. Very good to excellent length. Nicely focused and balanced. Best now to 2020. Score - 91. (David Lawrason, winealign.com, Nov. 4, 2016)"
#  ...
#  'Medium ruby with garnet tinges; aromas of red fruit candy, licorice and hints of oak; light, dry with spices on the finish.'
#  'This is a fresh and delicately fruity red with dark berry and hints of fresh herb. Medium body, fine tannins and a clean, bright and crisp finish. Drink now. Score - 92. (James Suckling, jamessuckling.com, April 5, 2018)'
#  'This generous and harmonious red is dense and smooth, delivering rich, deep flavors of plum, blackberry, coffee and mineral, with well-integrated tannins and balsamic acidity keeping it focused, but it stays plush through the spicy finish. Drink now through 2023.  Score - 92. (Thomas Matthews, winespectator.com, June 30, 2017)']
# pairings ['' 'Serve with weekend brunch, Cajun salmon burgers or on its own.'
#  'Perfect for creating any variety of cocktails!' ...
#  'Great with meat pasta, pizza, grilled or roasted meats, roast chestnuts and firm cheese.'
#  'Grilled steak, smoked sausages.' 'Burgers, ribs.']
# itemdescription ["'Méthode Cap Classique' is South African shorthand for the very same time-tested traditional method used to make Champagne. An incredible value, this pink example blends 85% Pinot Noir and 15% Chardonnay sourced from a 300-year-old farm. Look for tangy red berry and citrus notes, and sip with crispy duck breast or your favourite early-autumn appetizers."
#  ''
#  'Stratus has 10 red wine grapes in their vineyard: Cabernet Franc, Cabernet Sauvignon, Gamay, Malbec, Merlot, Petit Verdot, Sangiovese, Syrah, Tannat and Tempranillo. Winemaker J-L Groux, the blending maestro, and his team build this flagship red based on the qualities of the vintage. Based on the rave reviews the single-varietal 2015 Cabernet Franc is getting (two 90-point reviews from winealign.com, for instance), expect great things from this wine.'
#  'Crafted to be approachable and pleasing, this complex, evocative Merlot will deliver dark fruit, cassis and herbs, with touches of smoke, earth, mocha and spice. Try it with grilled lamb burgers.'
#  'The Candor Lot 7 Zinfandel is a non-vintage wine created by blending two, and sometimes three, vintages. This practice is integral to the likes of Champagne and was once fairly common for still wines but is now rare. Winemaker Austin Hope does it here to create a wine that simultaneously displays the depth of mature wines and the fresh forthrightness of younger ones. This Zin will offer a creamy-textured palate with layered, complex ripe dark berry fruit, spice and savoury undertones. Ideal for barbecued pork or lamb dishes.'
#  "Col Solare is the partnership between two winemaking giants: Tuscany's iconic Marchesi Antinori and Washington State's Chateau Ste. Michelle."
#  'This super-popular wine from the Delicato family is a perennial treat that delivers classic Cali cassis, with ripe black fruit delicately framed by toasty oak, spice and chocolate notes. This easy-to-enjoy wine has broad appeal and is always a winner with a crowd.'
#  'Gold Medal winner and Best in Show at the 2012 Royal Winter Fair.']
# liquortype ['Wine' 'Ciders' 'Non-Alc' 'Spirits' 'Beer'
#  'Accessories and Non-Alcohol Items' 'Ready-to-Drink/Coolers']
# categoryname ['Sparkling Wine' 'Red Wine' 'Cider' 'White Wine' '' 'Vodka' 'Hybrid'
#  'Gift and Sampler Packs' 'Whisky/Whiskey' 'Ale' 'Rum' 'Rosé Wine'
#  'Liqueur/Liquor' 'Specialty' 'Icewine' 'Brandy' 'Lager' 'Tequila'
#  'Champagne' 'Cognac/Armagnac' 'Fortified Wine' 'Specialty Wines'
#  'Charity Donation' 'Coolers' 'Premixed Cocktails' 'Grappa' 'Gin'
#  'Eau-de-Vie' 'Malt Beverages' 'Dessert Wine' 'Shochu/Soju'
#  'Radler/ Shandy' 'Bags & Boxes']
# stocktype ['VINTAGES' 'LCBO']
# subcategoryname ['Rosé/Red' '' 'Flavoured Cider' 'Unflavoured Vodka' 'Pale Hybrid Beer'
#  'Taster Pack' 'Irish Whiskey' 'India Pale Ale (IPA)' 'White'
#  'Bitters/Herbs' 'Dark' 'Stout' 'Sake/Rice Wine' 'Pale Lager'
#  'Canadian Whisky' 'Pale Ale' 'Sour' 'Flavoured Beer' 'Strong Lager'
#  'Reposado' 'Scotch Single Malts' 'XO' 'Red' 'Fruit Flavoured' 'Nut'
#  'Port' 'Belgian Strong Ale' 'Spice' 'Amber' 'New World Fortified'
#  'Traditional' 'Flavoured Wine' 'European Fortified' 'Cocktails'
#  'Premixed' 'Light Lager' 'Blanco' 'Regular' 'Caesars' 'Unique Selections'
#  'Floral' 'Bourbon/American Whiskey' 'Rosé' 'Scotch Whisky Blends' 'Cream'
#  'Sweet Flavours' 'Wheat & Rye' 'VSOP' 'Coffee' 'Niche'
#  'Vermouth/Aperitif' 'Sherry' 'Spiced' 'Aniseed' 'Fruit Spirit'
#  'Fruit Wine' 'Flavoured Vodka' 'Traditional Cider' 'VS' 'Pilsner'
#  'Amber Lager' 'Scottish & Irish Ale' 'Mezcal' 'Cider' 'Large Packs'
#  'Mint' 'Light' 'Porter' 'Añejo' 'Smoked & Barrel Aged Beer' 'Radler'
#  'Bock' 'Frozen Pouches' 'American Ale' 'Belgian Ale' 'Non-Alcohol'
#  'Strong Ale' 'Flavoured' 'Kolsch' 'Teas' 'Madeira/Marsala' 'Dark Lager'
#  'Amber Hybrid Beer' 'Citrus' 'Sour Ale' 'Brown Ale' 'Mixed' 'Sodas'
#  'Seltzers' 'International Whiskey' 'Shandy' 'Cachaca' 'Tropical' 'Shots'
#  'Sparkling' 'Dessert' 'Gluten Free' 'Mead' 'Bitter'
#  'Mixed (Flavoured & Traditional)' 'Wheat' 'Creams' 'Gluten Free Beer'
#  'Mixed Pack (Cider & Flavoured Cider)' 'Blonde Ale']
# sellingpackage ['bottle' 'can' 'gift' 'bagnbox' 'tetra' '']
# sweetnessdescriptor ['D - Dry' 'XD - Extra Dry' '' '-' 'M - Medium' 'MS - Medium Sweet'
#  'S - Sweet' 'MD -']
# winestyle ['Medium-bodied & Flavourful' 'Full-bodied & Smooth'
#  'Medium-bodied & Fruity' 'Medium-Sweet & Fruity' 'Full-bodied & Firm'
#  'Aromatic & Flavourful' '' 'Clean & Classic' 'Medium & Malty'
#  'Subtle & Fruity' 'Light & Crisp' 'Full-bodied & Rich' 'Subtle & Sweet'
#  'Medium-bodied & Dry' 'Clean & Fruity' 'Light-bodied & Fruity'
#  'Bold & Spicy' 'Medium & Roasted' 'Lusciously Sweet' 'Light & Malty'
#  'Medium & Herbal' 'Medium & Sweet' 'Off-dry & Fruity' 'Light & Hoppy'
#  'Medium & Fruity' 'Warm & Earthy' 'Bold & Floral' 'Rich & Complex'
#  'Medium & Hoppy' 'Sweet' 'Smooth & Fruity' 'Light & Fruity'
#  'Warm & Nutty' 'Easygoing & Fruity' 'Full & Malty' 'Warm & Spicy'
#  'Medium & Nutty' 'Luscious & Tropical Fruit' 'Medium & Spicy'
#  'Smooth & Nutty' 'Vibrant & Fruity' 'Luscious & Berry Fruit'
#  'Warm & Herbal' 'Bold & Oaky' 'Sweet & Fruity' 'Subtle & Floral'
#  'Subtle & Smoky' 'Bold & Nutty' 'Smooth & Spicy' 'Medium & Floral'
#  'Smooth & Creamy' 'Subtle & Spicy' 'Light & Spicy' 'Medium & Smoky'
#  'Smooth & Café' 'Bold & Sweet' 'Medium & Citrus' 'Light & Tart'
#  'Crisp & Citrus' 'Crisp & Fruity' 'Subtle & Toasty' 'Medium & Juniper'
#  'Warm & Sweet' 'Warm & Fruity' 'Subtle & Citrus' 'Medium & Oaky'
#  'Vibrant & Sweet' 'Bold & Fruity' 'Subtle & Herbal' 'Vibrant & Spicy'
#  'Dry' 'Medium' 'Soft & Off-dry' 'Bold & Berry' 'Dry & Rustic'
#  'Light & Floral' 'Bold & Smoky' 'Luscious & Dark Fruit' 'Smooth & Herbal'
#  'Clean & Citrus' 'Smooth & Classic' 'Warm & Toasty' 'Full & Hoppy'
#  'Vibrant & Earthy' 'Medium & Earthy' 'Bold & Citrus' 'Vibrant & Herbal'
#  'Subtle & Nutty' 'Full & Roasted' 'Clean & Spicy' 'Medium-Sweet & Crisp'
#  'Dry & Fruity' 'Subtle & Juniper' 'Smooth & Berry' 'Complex & Smoky'
#  'Bold & Classic' 'Crisp & Berry Fruit' 'Bold & Earthy' 'Bold & Café'
#  'Dry & Aromatic' 'Complex & Toasty' 'Bold & Juniper' 'Bold & Herbal'
#  'Medium & Toasty' 'Medium & Tart' 'Full & Spicy' 'Crisp & Tropical'
#  'Medium Sweet' 'Crisp & Dark Fruit' 'Lightly Sweet' 'Vibrant & Floral'
#  'Clean & Creamy' 'Dry & Crisp' 'Medium-Sweet & Spicy' 'Full & Fruity'
#  'Crisp & Tropical Fruit' 'Smooth & Citrus' 'Crisp & Berry'
#  'Smooth & Tropical' 'Sweet & Aromatic' 'Bold & Toasty' 'Vibrant & Tart'
#  'Clean & Herbal' 'Smooth & Sweet' 'Bold & Creamy' 'Crisp & Orchard Fruit'
#  'Bold & Cafe Flavours']
# winevarietal ['Sparkling' 'Pinot Noir' 'Gamay' 'Cabernet Franc/Merlot' 'Cider'
#  'Cabernet Franc' 'Red Blend' 'Syrah/Viognier' 'Riesling' ''
#  'Sauvignon Blanc' 'Corn' 'Cream Ale' 'Merlot' 'Ireland'
#  'Cabernet Sauvignon Blend' 'Blend' 'Tempranillo'
#  'Grenache/Syrah/Carignan' 'Gewürztraminer' 'Zinfandel' 'White Rum'
#  'Pinot Gris' 'Corvina/Rondinella/Molinara' 'Montepulciano' 'Barbaresco'
#  'Verdejo' 'Rosé' 'Chardonnay' 'Cabernet/Merlot' 'Cabernet Sauvignon'
#  'Malbec' 'Shiraz Blend' 'Dark Rum' 'Dry Stout' 'Wheat'
#  'Cabernet Sauvignon/Cabernet Franc/P' 'Prosecco' 'Icewine' 'Rioja'
#  'Bordeaux' 'North American Lager' 'European Lager' 'Canada' 'Taster Pack'
#  'Marsanne/Roussane' 'Chenin Blanc' 'Vinho Verde' 'Shiraz/Syrah'
#  'English Pale Ale' 'Sparkling - Sweet' 'Shiraz/Cabernet'
#  'Saperavi/Rkatsiteli' 'Viognier' 'Fruit Beer' 'Strong Lager'
#  'Sparkling - Dry' 'Syrah/Grenache' "Nero D'Avola" 'Carmenère'
#  'Scotland Other' 'Saperavi' 'Feteasca Neagra' 'Negroamaro'
#  'Scotland Malt' 'Sour' 'Malbec Blend' 'Pinot Blanc' 'Champagne'
#  'Cabernet Sauvignon/Sangiovese' 'Alentejo' 'Touriga Nacional Blend'
#  'Merlot Blend' 'Bohemian (Czech) Pilsner' 'Pinotage Blend' 'Syrah Blend'
#  'Grenache Blend' 'Meritage' 'Port' 'Cabernet Sauvignon/Merlot/Cabernet'
#  'Armagnac' 'Mencia' 'Sangiovese' 'Sauvignon Blanc/Sémillon' 'Ripasso'
#  'Pinot Noir/Chardonnay' 'Cortese' 'Nebbiolo'
#  'Merlot/Cabernet Sauvignon/Cabernet' 'Belgian Dubbel' 'Rum'
#  'Pinot Grigio' 'Corvina Blend' 'India Pale Ale (Ipa)' 'Riesling Kabinett'
#  'Sweet' 'Flavoured Wine' 'Scotland Blend' 'Touriga Nacional'
#  'Sangiovese Blend' 'Vin Doux Naturel' 'Corvina/Rondinella'
#  'Red - Light Fruity' 'Medium Sweet' 'Tempranillo Blend'
#  'Pinot Noir/Syrah' 'Tempranillo/Cabernet Sauvignon'
#  'Monastrell (Mourvèdre)' 'Cava' 'Rosé  - Dry' 'Viura/Malvasia' 'Kolsch'
#  'Brandy' 'Light Lager' 'English Ipa' 'Pinotage' 'Aglianico' 'Pecorino'
#  'Cabernet Franc/Cabernet Sauvignon' 'Merlot/Cabernet Sauvignon'
#  'Grenache Blanc Blend' 'Cabernet Sauvignon/Cabernet Franc' 'Grappa'
#  'Soave' 'Touriga Nacional/Tinta Roriz' 'Aperitif' 'Nero Di Troia'
#  'Savoury' 'Flavoured Beer' 'Barley' 'Liqueur' 'Rye' 'Usa Whiskey'
#  'White Blend' 'Premium Aged Rum' 'Shiraz/Cabernet Sauvignon'
#  'Blend Of Grains' 'Late Bottled Vintage Port' 'Tinta Roriz Blend'
#  'Belgian Pale Ale' 'Shiraz/Grenache' 'Sauternes' 'Riesling Spätlese'
#  'Ruby Port' 'Usa Bourbon' 'German Pilsner' 'Verdicchio' 'Amber Rum'
#  'Cabernet Sauvignon/Merlot' 'Barbera' 'Grüner Veltliner' 'Weizen'
#  'Dunkelweizen' 'Agiorgitiko' 'Chardonnay Blend' 'Garganega/Trebbiano'
#  'Whiskey - Usa' 'Whisky - Canada' 'Red - Sweet' 'Nerello Mascalese'
#  'Tannat/Cabernet Franc' 'Mavrodaphne' 'Single Malt Scotch'
#  'Aged Sour Beer' 'Tinta Fina' 'Potato' 'Beaujolais' 'Petite Sirah Blend'
#  'Bovale Sardo/Carignane/Grenache' 'Vermouth' 'Carignan' 'Crémant'
#  'Cream Sherry' 'Amarone' 'Shiraz/Merlot/Cabernet' 'Grain' 'Spiced Rum'
#  'Cabernet Franc Blend' 'Chianti' 'Dao' 'Negrette' 'India'
#  'Sauvignon Blanc Blend' 'Sangiovese/Cabernet Sauvignon' 'Bonarda'
#  'Pinot Meunier' 'Lightly Sweet' 'Baco Noir' 'Malbec/Cabernet Sauvignon'
#  'Rose' 'Belgian Wit' 'Viura (Macabeo)' 'Moscato' 'Dry Sherry' 'Dolcetto'
#  'Torrontes' 'Zweigelt' 'Riesling Blend' 'Pinot Noir Blend'
#  'Aragonés Blend' 'Saint Laurent' 'Douro' 'Moschofilero' 'Garnacha' 'Saké'
#  'Gin' 'American Pale Ale' 'Bordeaux Red' 'Brunello' 'Grenache Blanc'
#  'Cognac' 'Chardonnay Musqué' 'Cabernet Sauvignon/Petit Verdot' 'Vidal'
#  'Sémillon' 'Tokaji/Furmint' 'Primitivo' 'Altesse' 'Furmint'
#  'Fortified Wine' 'Castelão/Alicante Bouschet' 'Riesling Auslese'
#  'Grenache/Syrah/Mourvèdre' 'Shiraz/Viognier' 'Alvarinho/Albariño'
#  'Grenache' 'Weizenbock' "Moscato D'Asti" 'Baga' 'Grenache/Carignan'
#  'Vienna Lager' 'Moscatel' 'Trebbiano/Grechetto' 'Other' 'Irish Red Ale'
#  'Extra Special Bitter' 'American Ipa' 'Red - Medium Bodied'
#  'Malbec/Merlot' 'White - Light Dry' 'Vodka' 'Tequila'
#  'Monastrell (Mourvèdre) Blend' 'Grenache/Syrah' 'Antão Vaz Blend'
#  'Whisky - Scotch' 'Sangiovese/Canaiolo' 'Zinfandel/Petite Sirah'
#  'Zinfandel Blend' 'Chardonnay/Sauvignon Blanc' 'Grenache/Shiraz'
#  'Shiraz/Malbec' 'Chardonnay/Viognier' 'Corvina/Rondinella/Sangiovese'
#  'Valpolicella' 'Syrah/Grenache/Mourvèdre' 'Whiskey - Bourbon'
#  "Nero D'Avola/Syrah" 'Falanghina' 'Agiorgitiko/Cabernet Sauvignon'
#  'Viognier/Marsanne' 'Trebbiano' 'Barbera Blend' 'Xinomavro' 'Asian Lager'
#  'Tintilia' 'Symphony' 'Russian Imperial Stout' 'Rosé  - Sweet' 'Aligoté'
#  'Alvarinho' 'Shiraz/Merlot' 'White - Sweet' 'Red - Full Bodied'
#  'White - Full Bodied' 'Assyrtiko' 'Roussanne Blend' 'Petite Sirah'
#  'Fortified' 'Nerello Mascalese Blend' 'Cabernet Sauvignon/Syrah'
#  'Viognier Blend' 'Malbec/Tempranillo' 'Sherry Amontillado' 'Sweet Stout'
#  'Passerina' 'Fumin' 'Refosco Dal Peduncolo Rosso' 'Albana' 'Marsanne'
#  'Syrah/Mouvèdre/Grenache' 'Sagrantino' 'Scotch Ale' 'Cannonau (Grenache)'
#  'Vermentino' 'Porter' 'Grechetto Blend' 'Tannat' 'Corvina' 'Colombard'
#  'Roussanne' 'Mourvèdre' 'Müller-Thurgau' 'Scottish Ale' 'Radler'
#  'Tempranillo/Graciano' 'Grapes' 'Pinot Noir/Gamay' 'Traditional Bock'
#  'Sangiovese/Merlot' 'Petit Verdot' 'Syrah/Merlot' 'Mavroudi/Agiorgitiko'
#  'Fino Sherry' 'Roditis' 'Tempranillo/Grenache' 'Viognier/Chardonnay'
#  'Fruit Wine' 'Muscat' 'Carignan/Grenache'
#  'Sangiovese/Cabernet Sauvignon/Merlo' 'Insolia'
#  'Cabernet Sauvignon/Shiraz/Merlot' 'White - Fruity' 'Belgian Quadruple'
#  'Maibock' 'Eau-De-Vie' 'Picpoul Blanc' 'Cabernet/Carmenère/Syrah'
#  'Garganega' 'Casavecchia' 'Monica' 'Nuragus' 'Negrette Blend'
#  'Sauvignon Blanc/Chardonnay' 'Graciano' 'American Amber Ale' 'Savatiano'
#  'Saison' 'Belgian Dark Ale' "Nero D'Avola Blend" 'Syrah/Carignan'
#  'Blaufränkisch' 'Pinot Bianco' 'Friulano' 'Non-Alcohol' 'Debina'
#  'Syrah/Mourvèdre' 'Malvasia' 'Blonde Ale'
#  'Petit Verdot/Cabernet Sauvignon/Mer' 'Barolo' 'Barrel Aged Beer'
#  'Carignan Blend' 'Cabernet Sauvignon/Syrah/Carmenère' 'English Bitter'
#  'Bordeaux White' 'Grillo' 'Strong Ale' 'Primitivo Blend'
#  'Melon De Bourgogne' 'Sémillon/Sauvignon Blanc' 'Nebbiolo/Barbera'
#  'Pale Lager' 'Tempranillo/Mazuelo' 'Double Ipa' 'Pale Ale' 'Lambic'
#  'Merlot/Sangiovese' 'Fiano/Falanghina/Greco Bianco' 'Xinomavro Blend'
#  'Carricante/Catarratto' 'Xarel-Lo' 'Grasevina' 'Malvasia Fina Blend'
#  'Assyrtiko/Roditis' 'Chenin Blanc/Sémillon' 'Chenin Blanc Blend'
#  'Smoked Beer' 'Merlot/Cabernet Franc' 'Kirsch' 'Touriga Franca Blend'
#  'Schwarzbier' 'Carignan/Grenache/Syrah' 'Altbier' 'Kékfrankos' 'Fiano'
#  'Tocai Friulano Blend' 'Bobal Blend' 'Cabernet Sauvignon/Tempranillo'
#  'Verdelho' 'Greco Bianco' 'Loureiro' 'Sherry' 'Arinto' 'Clairette Blend'
#  'Munich Dunkel' 'Chasselas' 'Zibibbo' 'Marsanne Blend' 'Monica Blend'
#  'Malagousia' 'Ribolla Gialla' 'Late Harvest' 'Vranac'
#  'Cabernet Sauvignon/Malbec' 'Oktoberfest/Marzen' 'Flavoured Rum'
#  'Oatmeal Stout' 'Malbec/Cabernet Franc' 'Tawny Port' 'Session Ipa'
#  'Baga Blend' 'Belgian Blonde' 'Arinto Blend' 'Shiraz/Grenache/Mourvèdre'
#  'Niellucciu' 'Colombard/Chardonnay' 'Belgian Tripel' 'Alvarinho Blend'
#  'Black Ipa' 'American Wheat' 'Whiskey - Irish' 'Rkatsiteli'
#  'English Brown Ale' 'Mourvèdre Blend' 'Sémillon Blend' 'Cinsault'
#  'Touriga Nacional/Touriga Franca' 'Montepulciano/Sangiovese'
#  'Pinot Gris Blend' 'Golden Ale' 'Rubin Blend' 'Alicante Blend'
#  'Shiraz/Tempranillo' 'Kotsifali/Mandilari' 'Maréchal Foch'
#  'Refosco/Mavrodaphne' 'Carmenère Blend' 'Tokaj' 'Chardonnay/Sémillon'
#  'Malbec/Tannat' 'Kerner' 'Châteauneuf-Du-Pape' 'Grechetto' 'Rhône'
#  'Nebbiolo Blend' 'Grenache Noir Blend' 'Merlot/Malbec' 'Dessert Wine'
#  'Barbera/Nebbiolo' 'Colorino' 'Tamaioasa Romaneasca' 'Traminer'
#  'Gewurztraminer Blend' 'Sauvignon Blanc/Sémillon/Chardonna'
#  'Berliner Weisse' 'Shandy' 'Lagrein' 'Sylvaner' 'Corvina/Merlot'
#  'Sémillon/Sauvignon Blanc/Muscadell' 'Greco Di Tufo'
#  'Touriga Nacional/Syrah' 'Pumpkin Ale' 'Syrah/Malbec' 'Trincadeira Blend'
#  'Gewurztraminer/Riesling' 'Cabernet Sauvignon/Shiraz' 'Castelão Blend'
#  'Jaen' 'Gouveio (Verdelho)/Malvasia Fina/Vi' 'Whisky - Japan' 'Savagnin'
#  'Farmhouse Ale' 'Doppelbock' 'Grenache/Mourvèdre' 'Vidiano/Plyto'
#  'Aragonez/Trincadeira/Castelão/ Ali' 'Bobal' 'Frappato'
#  'Mourvèdre/Syrah/Grenache Noir' 'Gros Manseng' 'Gros Manseng Blend'
#  'Corvina/Raboso/Refosco' 'Aglianico/Sangiovese' 'Grenache/Tempranillo'
#  'Welschriesling' 'Gluten Free' 'Gose' 'Carmenere/Syrah'
#  'Primitivo/Negroamaro' 'Ehrenfelser' 'Muscat Blanc À Petits Grains'
#  'Silvaner' 'Mead' 'Avesso' 'Rye Ale' 'Scotch Blend' 'Godello'
#  'Vermentino/Grenache Blanc' 'California Common' 'Roussanne/Grenache'
#  'Pisco' 'Cabernet Sauvignon/Merlot/Tempranil' 'Syrah/Cabernet Sauvignon'
#  'Arneis' 'Dry Hopped Sour' 'Ugni Blanc/Colombard' 'Marsala' 'Spiced Beer'
#  'Petit Verdot/Cabernet Sauvignon' 'Garganega/Chardonnay' 'Burgundy'
#  'Moscatel/Gewurztraminer' 'Vin Santo' 'Piedirosso' 'Madeira'
#  'Pedro Ximénez' 'Pilsner' 'Flavoured Lager' 'Belgian Ale' 'Brown Ale'
#  'Feteasca Alba' 'Tannat Blend' 'Merlot/Corvina' 'Rkatsiteli/Mtsvane']
# stylebody ['Medium-bodied' 'Full-bodied' 'Medium-Sweet' 'Aromatic' '' 'Clean'
#  'Medium' 'Subtle' 'Light' 'Light-bodied' 'Bold' 'Off-dry' 'Warm' 'Rich'
#  'Smooth' 'Easygoing' 'Full' 'Luscious' 'Vibrant' 'Sweet' 'Crisp' 'Soft'
#  'Dry' 'Complex']
# stylebody_fr ['Mi-corsé' 'Corsé' 'Demi-doux' 'Aromatique' '' 'Nette' 'Mi-corsée'
#  'Léger' 'Puissant ' 'Légère' 'Demi-sec' 'Chaleureuse' 'Puissant' 'Riche'
#  'Moelleuse' 'Délicat' 'Gouleyant' 'Corsée' 'Onctueux' 'Veloutée' 'Vive'
#  'Doux' 'Affirmée' 'Vif' 'Affirmé' 'Souple' 'Sec' 'Complexe' 'Moelleux'
#  'Mi-corsé ']
# styleflavour ['Flavourful' 'Smooth' 'Fruity' 'Firm' '' 'Classic' 'Malty' 'Crisp' 'Rich'
#  'Sweet' 'Dry' 'Spicy' 'Roasted' 'Herbal' 'Hoppy' 'Earthy' 'Floral'
#  'Complex' 'Nutty' 'Tropical Fruit' 'Berry Fruit' 'Oaky' 'Smoky' 'Creamy'
#  'Café' 'Citrus' 'Tart' 'Toasty' 'Juniper' 'Off-dry' 'Berry' 'Rustic'
#  'Dark Fruit' 'Aromatic' 'Tropical' 'Orchard Fruit' 'Cafe Flavours']
# styleflavour_fr ['savoureux' 'souple' 'fruité' 'ferme' '' 'classique' 'maltée' 'vif'
#  'riche' 'doux' 'sec' 'fruitée' 'épicé' 'torréfiée' 'herbacé' 'houblonnée'
#  'terreuse' 'floral' 'complexe' 'noisetée' 'épicée' 'noiseté'
#  'saveur de fruits tropicaux' 'saveur de baies' 'herbacée' 'boisé' 'fumé'
#  'saveur de noix' 'crémeuse' 'à saveur de café' "notes d'agrumes"
#  'acidulée' 'èpicée' 'acidulé' 'torréfié' 'notes de genièvre' 'sucrée'
#  'epicé' 'demi-sec' 'à saveur de baies' 'florale' 'saveur de fruits noirs'
#  'douce' 'terreux' 'fumée' 'grillée' 'saveur d agrumes' 'aromatique'
#  ' vif' 'tropical' 'crémeux' 'saveur de fruits du verger' 'sèche'
#  'saveur de café' 'saveur épicée']
# quantity [ 1  6  4 24 12 15  8 28  3 20 10  2  5 18 36]
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# Filter on Whisky

# %%
whisky_df = full_df[full_df['categoryname'] == 'Whisky/Whiskey']

# %%
whisky_df.to_parquet('data/lcbo_whisky.parquet')
