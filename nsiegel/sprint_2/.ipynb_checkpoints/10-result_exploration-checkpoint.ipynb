# %% [markdown]
# ## Load Libraries and Data

# %%
import pandas as pd

# %%
whiskyt = pd.read_parquet('data/whisky_tfidf.parquet')
similarities = pd.read_parquet('data/similarities.parquet')
lcbo = pd.read_parquet('../sprint_1/data/lcbo_whisky.parquet')

# %% [markdown]
# ## Create Dataframe of all Whisky Info
# To do this we will add some metrics such as price per 750ml and price per rating

# %%
whiskyinfo = (whiskyt.reset_index()
                     .drop({'Name'},axis=1)
                     .set_index('itemnumber')
                     .join(lcbo.set_index('itemnumber'))
                     .assign(price_per_750 = lambda row: row['quantity']*row['price']*750/row['productsize'])
                     .assign(rating_per_dollar_per_750 = lambda row: row['rating_mean']/row['price_per_750'])
            )

whiskyinfo.to_parquet('data/whiskyinfo.parquet')

# %%
columns = ['itemname','rating_mean','price','quantity','productsize','price_per_750','rating_per_dollar_per_750']
whiskyinfo[columns].head()
# Out:
#                                                      itemname  rating_mean  \
# itemnumber
# 619320       12 YO KNAPPOGUE CASTLE IRISH SINGLE MALT WHISKEY    75.100000
# 496729      1792 SINGLE BARREL KENTUCKY STRAIGHT BOURBON W...    72.166667
# 208918             1792 SMALL BATCH KENTUCKY STRAIGHT BOURBON    76.200000
# 634519                                            601 BOURBON    58.000000
# 255281                                  ABERFELDY 12 YEAR OLD    76.931034
#
#             price  quantity  productsize  price_per_750  \
# itemnumber
# 619320      73.85         1          750          73.85
# 496729      62.10         1          750          62.10
# 208918      50.20         1          750          50.20
# 634519      57.95         1          750          57.95
# 255281      60.95         1          750          60.95
#
#             rating_per_dollar_per_750
# itemnumber
# 619320                       1.016926
# 496729                       1.162104
# 208918                       1.517928
# 634519                       1.000863
# 255281                       1.262199

# %% [markdown]
# ## Functions to Show Matches

# %%
# Function to find top matches and get info
def show_top_similarities(itemnumber, top_n=5):
    return (similarities[(similarities['itemnumber'] == itemnumber) & 
             (similarities['itemnumber'] != similarities['itemnumber2'])]
                 .sort_values('sim', ascending=False)
                 .head(top_n)
                 .drop({'nose_sim','taste_sim','finish_sim','itemnumber'},axis=1)
                 .rename({'itemnumber2':'itemnumber','sim':'similarity'},axis=1)
                 .set_index('itemnumber')
                 .join(whiskyinfo)
                 #.drop({'nose','taste','finish'},axis=1)
                 #.rename({'nose_tfidf':'nose','taste_tfidf':'taste','finish_tfidf':'finish'},axis=1)
    )

# Function to find a whiskyID to use in the lookup
def findwhisky(name):
    return whiskyp.reset_index()[whiskyp.reset_index()['Name'].str.contains(name.upper())][['itemnumber','Name']]

# Function to print whisky descriptions:
def printwhiskydesc(itemnumber):
    whisky = whiskyinfo.reset_index()[whiskyt.reset_index()['itemnumber']==itemnumber]
    name = whisky.itemname.values
    price = str(whisky.price.values)
    size = str(whisky.productsize.values)
    rating = str(whisky.rating_mean.values)
    rating_per_dollar_per_750 = str(whisky.rating_per_dollar_per_750.values)
    nose = whisky['nose'].apply(lambda x : ' '.join(x)).values
    taste = whisky['taste'].apply(lambda x : ' '.join(x)).values
    finish = whisky['finish'].apply(lambda x : ' '.join(x)).values
    
    print('Name: ' + name)
    print(' ')
    print('Price: ' + price + ' per ' + size + 'ml')
    print('Rating: ' + rating)
    print('Rating/$/750ml: ' + rating_per_dollar_per_750)
    print(' ')
    print('Nose: ' + nose)
    print(' ')
    print('Taste: ' + taste)
    print(' ')
    print('Finish: ' + finish)
    print(' ')
    
# Function to show all suggestions and details of the top suggestion
def displaysuggestions(itemnumber, sort='rating_per_dollar_per_750', top_n = 5):
    columns = ['itemname',
              'similarity', 'rating_per_dollar_per_750','rating_mean','price','productsize',
              'style',
               'nose','taste','finish'
              ]
    results = show_top_similarities(itemnumber, top_n)[columns].sort_values(sort,ascending=False)
    # Print main results
    display(results)
    # Print info about search whisky
    printwhiskydesc(itemnumber)
    # Print info about top match whisky
    printwhiskydesc(results.reset_index().itemnumber.iloc[0])

# %% [markdown]
# ## Test Suggestions

# %% [markdown]
# ### Islay Scotch: Laphroaig 10

# %%
# Find a whisky ID
findwhisky('Laphroaig 10')
# Out:
#      itemnumber                                               Name
# 265      248997  LAPHROAIG 10 YEAR OLD ISLAY SINGLE MALT SCOTCH...

# %%
displaysuggestions(248997)
# Out:
#                                                      itemname  similarity  \
# itemnumber
# 19158       LAPHROAIG QUARTER CASK ISLAY SINGLE MALT SCOTC...    0.727425
# 560474                 ARDBEG 10 YEAR OLD ISLAY SCOTCH WHISKY    0.738969
# 249680         TALISKER 10 YEAR OLD SINGLE MALT SCOTCH WHISKY    0.707272
# 207126      LAGAVULIN 16 YEAR OLD ISLAY SINGLE MALT SCOTCH...    0.718734
# 455436         LAPHROAIG LORE ISLAY SINGLE MALT SCOTCH WHISKY    0.679404
#
#             rating_per_dollar_per_750  rating_mean   price  productsize  \
# itemnumber
# 19158                        0.976320    87.478261   89.60          750
# 560474                       0.859718    86.143750  100.20          750
# 249680                       0.816912    85.939189  105.20          750
# 207126                       0.644943    87.196319  135.20          750
# 455436                       0.432398    84.641975  195.75          750
#
#              style                                               nose  \
# itemnumber
# 19158        Islay  [peat, smoke, medicinal, iodine, laphroaig, se...
# 560474       Islay  [peat, smoke, sea, brine, iodine, campfire, me...
# 249680      Island  [smoke, peat, sea, brine, salt, pepper, salty,...
# 207126       Islay  [peat, smoke, iodine, campfire, medicinal, she...
# 455436       Islay  [peat, medicinal, smoke, laphroaig, seaweed, i...
#
#                                                         taste  \
# itemnumber
# 19158       [peat, smoke, medicinal, iodine, brine, salt, ...
# 560474      [peat, smoke, medicinal, like, sweetness, iodi...
# 249680      [smoke, peat, salt, brine, oily, salty, sea, s...
# 207126      [peat, smoke, like, iodine, sherry, brine, sal...
# 455436      [smoke, peat, medicinal, ash, iodine, brine, l...
#
#                                                        finish
# itemnumber
# 19158       [smoke, peat, medicinal, iodine, linger, dry, ...
# 560474      [smoke, peat, linger, taste, peaty, like, mout...
# 249680      [smoke, peat, pepper, salt, linger, dry, warm,...
# 207126      [smoke, peat, smoky, linger, lingers, taste, s...
# 455436      [smoke, peat, ash, proof, peaty, ashy, sweetne...
# ['Name: LAPHROAIG 10 YEAR OLD ISLAY SINGLE MALT SCOTCH WHISKY']
#
# Price: [74.95] per [750]ml
# Rating: [84.79452055]
# Rating/$/750ml: [1.13134784]
#
# ['Nose: peat smoke iodine medicinal sea salt seaweed campfire laphroaig brine smell burning like band meat rubber bacon wet coal wood toffee strong salty ash medicine charcoal sweetness air slight citrus leather earthy lemon beach immediately earth hint ocean aid water burnt flavor big tar moss face sweeter old present come']
#
# ['Taste: smoke peat iodine sweetness meat salt ash medicinal sea brine seaweed like campfire nose oily rubber coal little bacon smokey mouthfeel peaty water salty hint slight feel wood earthy rich tongue flavor dry smooth laphroaig grass citrus ashy damp char smoky strong mouth smokiness wet leather tobacco peppery malt smell']
#
# ['Finish: smoke peat medicinal iodine smoky smokey linger sweetness taste like salt stay mouth earthy peaty note flavor ash burn tar feel little salty smooth fade good laphroaig warm bit hint throat end tongue lingers pleasant smokiness love dry leaf pepper satisfy charcoal wet thing actually longer wood sea come slowly']
#
# ['Name: LAPHROAIG QUARTER CASK ISLAY SINGLE MALT SCOTCH WHISKY']
#
# Price: [89.6] per [750]ml
# Rating: [87.47826087]
# Rating/$/750ml: [0.97631988]
#
# ['Nose: peat smoke medicinal iodine laphroaig seaweed sea brine campfire like rubber salt tar meat wet strong wood leather old ash earth peaty hint spice red sherry smell little dry air citrus mineral toffee salty burnt sweetness pepper alcohol pork powerful coconut fish pear dark room band maybe berry fresh year']
#
# ['Taste: peat smoke medicinal iodine brine salt ash sweetness meat like smoky seaweed sea burnt nose citrus wood hint sherry wow dry tobacco spicy laphroaig salty water flavor rubber peaty char finish campfire oily lemon little raisin soot bacon mouth chocolate leather tongue dark lot way jam come charcoal bitter mouthfeel']
#
# ['Finish: smoke peat medicinal iodine linger dry sweetness pepper ash smoky like note wood vanilla peaty taste want brine lingers salt bitter smokey bit warm spice warmth smooth laphroaig way little hot peppery char salty spicy nose flavor sherry light come rough fruit thing cask campfire hint mouth time longer chocolate']

# %% [markdown]
# ### Bourbon:  Wild Turkey Rare Breed

# %%
findwhisky('Wild Turkey')
# Out:
#      itemnumber                                              Name
# 405      479949         WILD TURKEY 101 KENTUCKY STRAIGHT BOURBON
# 406      281824    WILD TURKEY 81 PROOF KENTUCKY STRAIGHT BOURBON
# 407      575001                            WILD TURKEY LONGBRANCH
# 408      455329  WILD TURKEY RARE BREED KENTUCKY STRAIGHT BOURBON

# %%
displaysuggestions(455329)
# Out:
#                                                      itemname  similarity  \
# itemnumber
# 426148                                           OLD FORESTER    0.702636
# 467969      WELLER ANTIQUE 107 ORIGINAL WHEATED STRAIGHT B...    0.687649
# 479949              WILD TURKEY 101 KENTUCKY STRAIGHT BOURBON    0.737558
# 256230                         FOUR ROSES SMALL BATCH BOURBON    0.711151
# 288878      COLONEL E.H. TAYLOR SINGLE BARREL KENTUCKY STR...    0.685938
#
#             rating_per_dollar_per_750  rating_mean  price  productsize  \
# itemnumber
# 426148                       2.519490    83.647059  33.20          750
# 467969                       2.368516    85.148148  35.95          750
# 479949                       1.927333    82.778947  42.95          750
# 256230                       1.819818    87.715232  48.20          750
# 288878                       0.867939    85.925926  99.00          750
#
#               style                                               nose  \
# itemnumber
# 426148      Bourbon  [rye, spice, proof, bourbon, ish, cinnamon, ba...
# 467969      Bourbon  [cinnamon, cherry, sugar, alcohol, brown, clov...
# 479949      Bourbon  [spice, rye, cinnamon, spicy, sugar, bourbon, ...
# 256230      Bourbon  [rye, cherry, cinnamon, spice, bourbon, corn, ...
# 288878      Bourbon  [corn, cherry, like, proof, sugar, ethanol, ry...
#
#                                                         taste  \
# itemnumber
# 426148      [old, banana, cinnamon, cherry, finish, like, ...
# 467969      [cinnamon, cherry, sugar, brown, sweetness, ho...
# 479949      [cinnamon, rye, cherry, spicy, medium, mint, c...
# 256230      [rye, cherry, cinnamon, dry, mint, little, cho...
# 288878      [proof, like, sugar, cherry, flavor, rye, cinn...
#
#                                                        finish
# itemnumber
# 426148      [vanilla, caramel, note, mint, cherry, corn, s...
# 467969      [cinnamon, burn, vanilla, cherry, caramel, war...
# 479949      [spice, vanilla, cinnamon, rye, caramel, littl...
# 256230      [spice, cherry, rye, vanilla, note, dry, caram...
# 288878      [vanilla, spice, pepper, caramel, proof, sligh...
# ['Name: WILD TURKEY RARE BREED KENTUCKY STRAIGHT BOURBON']
#
# Price: [65.75] per [750]ml
# Rating: [84.13013699]
# Rating/$/750ml: [1.27954581]
#
# ['Nose: spice cinnamon spicy rye sugar cherry wild old toffee bourbon brown musty wood corn smell leather clove chocolate proof tobacco peanut mint little hint funk dark rich baking black char like pepper depth alcohol big nice sweetness fruity year touch lot cocoa profile forward menthol citrus finish butter classic strong']
#
# ['Taste: cinnamon rye mouthfeel cherry wild peanut spicy rich proof little flavor nice dry lot sweetness bourbon heat orange black high chocolate clove like butter corn nose depth oaky hint good candy hot mint wood dark hotter sugar finish classic toffee cocoa bitter char medium balance maybe old tobacco syrup profile']
#
# ['Finish: spice caramel oaky vanilla cherry mint linger dry bit rye note cinnamon spicy sweetness lingers nice flavor pepper peanut tannic lot char bitter like heat barrel bourbon warm fade big warmth palate sugar black astringency corn end little proof good mouth balance cocoa tart hot sweeter butter touch come hots']
#
# ['Name: OLD FORESTER']
#
# Price: [33.2] per [750]ml
# Rating: [83.64705882]
# Rating/$/750ml: [2.51948972]
#
# ['Nose: rye spice proof bourbon ish cinnamon banana sugar like brown smell base cherry consider bubble age decent gum minute mint classic nutmeg molasses leather mash hot touch high nice paint char peanut clove citrus little orange wood corn pepper hint standard strong dark black flavor maple fig syrup sawdust dusty']
#
# ['Taste: old banana cinnamon cherry finish like whiskey bubble average upfront mint bourbon depth guess gum good year nose middle youth flavor carry slightly dark end chocolate nice lot sweetness combine bitter young fruitiness maple dry hot rye syrup proof spicy mash pretty mix warm nut clove sugar black medium mouthfeel']
#
# ['Finish: vanilla caramel note mint cherry corn spice bit warm linger pepper flavor sweetness black lingers nice orange hint burn cinnamon oaky warmth dry fruit belly fudge way slightly heat peanut banana leaf little rye pleasant throat bitter tannic good mouth sugar candy cream peppermint end aftertaste taste wave floral minty']

# %% [markdown]
# ### Unconventional Islay Scotch: Bruichladdich Classic Laddie

# %%
findwhisky('Bruichladdich')
# Out:
#     itemnumber                                              Name
# 61      459024                   BRUICHLADDICH ISLAY BARLEY 2009
# 62      387423  BRUICHLADDICH THE CLASSIC LADDIE SCOTTISH BARLEY
# 63      551820                    BRUICHLADDICH THE ORGANIC 2009

# %%
displaysuggestions(387423)
# Out:
#                                                      itemname  similarity  \
# itemnumber
# 192732      CRAGGANMORE 12 YEAR OLD SINGLE MALT SCOTCH WHISKY    0.635314
# 459024                        BRUICHLADDICH ISLAY BARLEY 2009    0.650577
# 250357        CLYNELISH 14 YEAR OLD SINGLE MALT SCOTCH WHISKY    0.632920
# 241943      GLENMORANGIE LASANTA EXTRA MATURED HIGHLAND SI...    0.637357
# 500231      HIGHLAND PARK 18 YEAR OLD SINGLE MALT SCOTCH W...    0.631513
#
#             rating_per_dollar_per_750  rating_mean   price  productsize  \
# itemnumber
# 192732                       1.186513    79.021739   66.60          750
# 459024                       1.060742    84.806306   79.95          750
# 250357                       0.921000    81.876923   88.90          750
# 241943                       0.838834    77.885714   92.85          750
# 500231                       0.431647    86.329412  200.00          750
#
#                style                                               nose  \
# itemnumber
# 192732      Speyside  [pear, floral, malt, almond, dry, subtle, smok...
# 459024         Islay  [peat, smoke, lemon, salt, sea, salty, fresh, ...
# 250357      Highland  [candle, wax, orange, floral, malt, citrus, fr...
# 241943      Highland  [sherry, orange, raisin, dry, wine, floral, ci...
# 500231        Island  [smoke, peat, sherry, toffee, brine, salt, cho...
#
#                                                         taste  \
# itemnumber
# 192732      [smoke, almond, creamy, malty, salty, peat, nu...
# 459024      [peat, smoke, salt, salty, lemon, barley, malt...
# 250357      [malt, smoke, mouthfeel, orange, feel, little,...
# 241943      [sherry, orange, raisin, wine, like, nose, sug...
# 500231      [smoke, peat, toffee, brine, salt, chocolate, ...
#
#                                                        finish
# itemnumber
# 192732      [smoke, bit, honey, light, linger, hint, dry, ...
# 459024      [peat, smoke, dry, salty, honey, bit, vanilla,...
# 250357      [dry, waxy, smoke, pepper, malt, honey, pineap...
# 241943      [sherry, fruit, spice, pepper, honey, bitter, ...
# 500231      [smoke, peat, dry, salt, chocolate, toffee, sp...
# ['Name: BRUICHLADDICH THE CLASSIC LADDIE SCOTTISH BARLEY']
#
# Price: [70.25] per [750]ml
# Rating: [81.97368421]
# Rating/$/750ml: [1.16688518]
#
# ['Nose: smoke peat fresh floral wine bubble barley melon gum salty malt dry faint salt plum peach sea pineapple pear raspberry lemon cut honeydew citrus strawberry like funk chocolate little cream subtle grass slight maybe zest raisin red crisp coastal malty white spice fig blueberry ripe cherry highland small scent wet']
#
# ['Taste: salt salty lemon mint sugar smoke malt brine barley floral sea bubble pear melon grape gum chocolate toast heat nice peat nectarine delicious green lot raisin banana orange cocoa cherry pith spicy malty peach citrus coconut pineapple sweetness butter nose sugary clean raw like red powder brown tounge ton prune']
#
# ['Finish: smoke linger salty warm honey vanilla note apple peat heat faint acidic ice burn barbecue dry accompany white port bit sugar pepper lime sauce cherry orange little sweetness hay light malt herbal strong citrus follow highland marzipan acidity warmth toffee whisky cereal mid saltiness quick tea melon lemon spice lingers']
#
# ['Name: CRAGGANMORE 12 YEAR OLD SINGLE MALT SCOTCH WHISKY']
#
# Price: [66.6] per [750]ml
# Rating: [79.02173913]
# Rating/$/750ml: [1.1865126]
#
# ['Nose: pear floral malt almond dry subtle smoke cherry zest citrus heather peat woody fresh sherry orange polish raisin fruity red malty hint roast touch faint smell strong sweetness reminds spice prune heavy wood alcohol jam jpg coriander medium sugar like dark blossom cocoa syrup wet rose chocolate soft http juice']
#
# ['Taste: smoke almond creamy malty salty peat nutty lemon nose pear strong raisin hint toast pith cereal nut peppery malt sweetness touch sherry smooth orange fruity floral oily cinnamon cheerio easy end shortbread spicy heat juicy mild flake richer alcohol cream cherry flavor salt background ginger strawberry wood dry expect delicate']
#
# ['Finish: smoke bit honey light linger hint dry peppery quick lemon little tea port cigar pepper spice mouth smoky astringent bitterness saltiness malt end warm non lingers vanilla nice longer herbal tongue cherry bitter hot smokiness mild fruit peat sour quickly cough warmth heat come burn decent zest ginger hang citrus']

# %% [markdown]
# ### Irish: Redbreast 15

# %%
findwhisky('Redbreast')
# Out:
#      itemnumber                                    Name
# 313      446781     REDBREAST 15 YEAR OLD IRISH WHISKEY
# 314      446799     REDBREAST 21 YEAR OLD IRISH WHISKEY
# 315      481218  REDBREAST LUSTAU EDITION IRISH WHISKEY

# %%
displaysuggestions(446781)
# Out:
#                                                      itemname  similarity  \
# itemnumber
# 481218                 REDBREAST LUSTAU EDITION IRISH WHISKEY    0.607886
# 446807                              YELLOW SPOT IRISH WHISKEY    0.620087
# 530352      GLENFIDDICH 18 YEAR OLD SINGLE MALT SCOTCH WHISKY    0.601423
# 446799                    REDBREAST 21 YEAR OLD IRISH WHISKEY    0.613341
# 446757        MIDLETON BARRY CROCKETT LEGACY SINGLE POT STILL    0.620611
#
#             rating_per_dollar_per_750  rating_mean   price  productsize  \
# itemnumber
# 481218                       0.901673    79.933333   88.65          750
# 446807                       0.871204    85.857143   98.55          750
# 530352                       0.467481    84.216667  180.15          750
# 446799                       0.358352    87.545455  244.30          750
# 446757                       0.290200    87.800000  302.55          750
#
#                style                                               nose  \
# itemnumber
# 481218       Ireland  [sherry, raisin, accord, wife, cinnamon, usual...
# 446807       Ireland  [grape, dense, nice, fruity, red, subtle, abv,...
# 530352      Speyside  [sherry, wood, pear, fresh, toffee, cinnamon, ...
# 446799       Ireland  [golden, concentrate, old, pineapple, wood, ma...
# 446757       Ireland  [pot, peach, single, grassy, creamy, mention, ...
#
#                                                         taste  \
# itemnumber
# 481218      [sherry, slightly, creamy, marzipan, damn, pea...
# 446807      [sherry, copper, red, mature, nice, malt, port...
# 530352      [sherry, orange, dry, pear, sugar, mouthfeel, ...
# 446799      [raspberry, cream, pear, join, malt, rich, min...
# 446757      [complexity, tea, port, cinnamon, sherry, red,...
#
#                                                        finish
# itemnumber
# 481218      [bit, warmth, spice, sherry, surprised, little...
# 446807      [copper, bit, note, vanilla, pretty, tad, high...
# 530352      [spice, apple, smooth, bit, note, pear, pleasa...
# 446799      [mango, spice, barley, pineapple, pepper, clov...
# 446757      [tad, harshness, sandalwood, floral, thyme, de...
# ['Name: REDBREAST 15 YEAR OLD IRISH WHISKEY']
#
# Price: [122.8] per [750]ml
# Rating: [85.55555556]
# Rating/$/750ml: [0.69670648]
#
# ['Nose: sherry stay accord wife finish malt floral creamy score fresh toffee apricot cinnamon almond close biscuit hazelnut spice metallic rich yeast come raisin somewhat dry banana licorice influence acetone raspberry spicy hint calm power head batter main milder pineapple flour previous pot play malty bourbon fantastic ginger esque solventy mint']
#
# ['Taste: malt sherry cream creamy oily water pie raspberry fresh rich sugar slightly bland red near brown come bean port waxy begin mild flavour crisp metallic mint butter raisin alcohol smooth texture syrup round flavor nice hint add warm like cinnamon talk its echo bread generic way pretty apricot grass curry']
#
# ['Finish: bit spice chip peel fresh aftertaste red apple light water tad pineapple pepper vanilla lemon rye whisky corn little like cinnamon grape wood leather leaf note harshness sherry way dry slightest cherry clove tangerine smooth marzipan tannin winey vinegar fruity acrid citrusy come imagine dessert pastry bitterness remind lead malt']
#
# ['Name: REDBREAST LUSTAU EDITION IRISH WHISKEY']
#
# Price: [88.65] per [750]ml
# Rating: [79.93333333]
# Rating/$/750ml: [0.90167325]
#
# ['Nose: sherry raisin accord wife cinnamon usually consider bready dense green point chocolate bomb definite lot proof nut orange plum almond biscuit cranberry prune come marzipan malt brown kind air fresh cask definitely floral sugar spice cheerio main closer familiar pot fair previous cereal black grain solventy grape neutral dirty clover']
#
# ['Taste: sherry slightly creamy marzipan damn peach grape proof orange mouthfeel oily add classic dominant waxy warmth hot green raisin come citrus malt chocolate little zest definitely nose influence cinnamon talk easygoing its rubbery bunch way start pretty nougat usual bar leather mild maybe honeydew mocha copper bomb medium nutty balance']
#
# ['Finish: bit warmth spice sherry surprised little waxy favorite nut bittersweet mouthfeel bitter tad complex profile proof malt actually fresh dram sweetness cinnamon apple almond fruit raisin linger green fairly note aftertaste way chewy yo extra papaya blackberry marzipan golden lot gently gingerbread come blueberry moderately noticeable jam end particularly whiskey']

# %% [markdown]
# ### Japanese: Toki

# %%
findwhisky('Toki')
# Out:
#      itemnumber  Name
# 383      465484  TOKI

# %%
displaysuggestions(465484, sort='similarity')
# Out:
#                                                      itemname  similarity  \
# itemnumber
# 481226                                         HIBIKI HARMONY    0.652634
# 238097      DALWHINNIE 15 YEAR OLD SINGLE HIGHLAND MALT SC...    0.592760
# 289496           CARDHU 12 YEAR OLD SINGLE MALT SCOTCH WHISKY    0.592553
# 69435       GLENKINCHIE 12 YEARS OLD LOWLAND SINGLE MALT S...    0.588918
# 250357        CLYNELISH 14 YEAR OLD SINGLE MALT SCOTCH WHISKY    0.586270
#
#             rating_per_dollar_per_750  rating_mean   price  productsize  \
# itemnumber
# 481226                       0.656156    78.705882  119.95          750
# 238097                       0.774003    81.270270  105.00          750
# 289496                       0.980196    76.406250   77.95          750
# 69435                        0.869743    76.972222   88.50          750
# 250357                       0.921000    81.876923   88.90          750
#
#                style                                               nose  \
# itemnumber
# 481226         Japan  [distinctive, grain, spice, place, fresh, whit...
# 238097      Highland  [floral, smoke, hint, malt, orange, citrus, he...
# 289496      Speyside  [smoke, malt, pear, bran, peat, barley, wood, ...
# 69435        Lowland  [floral, lemon, pear, malt, wood, malty, green...
# 250357      Highland  [candle, wax, orange, floral, malt, citrus, fr...
#
#                                                         taste  \
# itemnumber
# 481226      [grain, sherry, pear, blend, touch, lightly, s...
# 238097      [smoke, malt, like, water, citrus, floral, pea...
# 289496      [smoke, peat, salt, slight, oily, like, pear, ...
# 69435       [smoke, citrus, malty, white, lemon, creamy, l...
# 250357      [malt, smoke, mouthfeel, orange, feel, little,...
#
#                                                        finish
# itemnumber
# 481226      [grass, waxy, tree, grain, honey, apple, light...
# 238097      [smoke, honey, linger, malt, flavor, dry, bit,...
# 289496      [bit, dry, linger, pepper, peat, smoke, heat, ...
# 69435       [burn, dry, taste, white, bit, sour, cereal, c...
# 250357      [dry, waxy, smoke, pepper, malt, honey, pineap...
# ['Name: TOKI']
#
# Price: [54.95] per [750]ml
# Rating: [71.5]
# Rating/$/750ml: [1.30118289]
#
# ['Nose: pear white grape floral green gentle brine citrus flower spice sweat wine malty sock faint honeycomb aspect grass base characteristic harsh fruity barely smoke definite banana bouquet hint delicate wheat simple different mix iodine crisp burn follow somewhat rum influence grassy melon tea coconut reminds oaky hay old apricot ginger']
#
# ['Taste: dryness grain pear like main oaky white slight floral odd tea grass tongue bitterness whisky fresh tingle nice grassy blend taste reminds ginger fairly mouthfeel juice spread apples trail general malty bar hot glaze chocolatey sherry trace cream honeysuckle element skin creamy continue pith layer weird seed left classic citrus']
#
# ['Finish: clean like waxy linger dry light white juice grape grain aftertaste good citrusy tone ginger flat plastic cranberry smoke hard sweetness build crisp grapefruit honey hay blend ashy sharp bit syrupy lightly medicinal grass drink peach grassy smoky tannic fairly pear balance floral time alcohol warmth fruity salt bitterness slightly']
#
# ['Name: HIBIKI HARMONY']
#
# Price: [119.95] per [750]ml
# Rating: [78.70588235]
# Rating/$/750ml: [0.65615575]
#
# ['Nose: distinctive grain spice place fresh white floral touch faint grass perfume pear banana brine influence citrus woody flower cordial demerara croissant pineapple brioche apricot malty plum woodiness exotic rich aspect bark honeydew shortbread base quickly peach cantaloupe watermelon harsh restrain sweetness rice raisin fruity aromatic load barely bubblegum smoke currant']
#
# ['Taste: grain sherry pear blend touch lightly smooth odd juice orange cider clean malty whisky white creamy pick nice salt taste bad ginger citrus oil baking sugary fairly oaked cinnamon like associate rotten oiliness think apples carrot lick toast grass trail general needle rice follow nut hate bud drier bar maybe']
#
# ['Finish: grass waxy tree grain honey apple light floral fruity young fading return smoky smoke like bit note spice type bark lavender white rosemary live alcohol salt pastry bake stone immediately tingly use woodiness plastic cider chocolate hard best build hay sense wood tiny pick blend fruit ashy sharp swallow reminds']

# %% [markdown]
# ### Canadian: Wiser's Dissertation

# %%
findwhisky('Crown')
# Out:
#      itemnumber                                Name
# 108      403519                   CROWN ROYAL APPLE
# 109      224352                   CROWN ROYAL BLACK
# 110      276618            CROWN ROYAL BLACK WHISKY
# 111      246603  CROWN ROYAL LIMITED EDITION WHISKY
# 112      312801          CROWN ROYAL MAPLE FINISHED
# 113      434092    CROWN ROYAL NORTHERN HARVEST RYE
# 114      321208         CROWN ROYAL SPECIAL RESERVE
# 115        1487                  CROWN ROYAL WHISKY
# 116      438911                      CROWN ROYAL XO

# %%
displaysuggestions(1487)
# Out:
#                                       itemname  similarity  \
# itemnumber
# 434092        CROWN ROYAL NORTHERN HARVEST RYE    0.608951
# 54866         BULLEIT BOURBON FRONTIER WHISKEY    0.616471
# 482729                         BULLEIT BOURBON    0.616471
# 246603      CROWN ROYAL LIMITED EDITION WHISKY    0.637496
# 321208             CROWN ROYAL SPECIAL RESERVE    0.644717
#
#             rating_per_dollar_per_750  rating_mean  price  productsize  \
# itemnumber
# 434092                       2.167031    77.904762  35.95          750
# 54866                        1.866432    80.163265  42.95          750
# 482729                       1.709238    80.163265  23.45          375
# 246603                       1.647232    68.277778  41.45          750
# 321208                       1.127606    67.600000  59.95          750
#
#               style                                               nose  \
# itemnumber
# 434092       Canada  [rye, smell, spice, clove, like, hint, generic...
# 54866       Bourbon  [rye, spice, cinnamon, dill, bourbon, corn, su...
# 482729      Bourbon  [rye, spice, cinnamon, dill, bourbon, corn, su...
# 246603       Canada  [maple, rye, bourbon, prickle, peach, wife, sy...
# 321208       Canada  [maple, rye, alcohol, sugar, sort, bourbon, gr...
#
#                                                         taste  \
# itemnumber
# 434092      [rye, canadian, whisky, like, butterscotch, hi...
# 54866       [rye, cinnamon, mint, corn, spicy, bourbon, ni...
# 482729      [rye, cinnamon, mint, corn, spicy, bourbon, ni...
# 246603      [rye, canadian, brings, juniper, maple, whisky...
# 321208      [rye, batch, royal, canadian, maple, course, t...
#
#                                                        finish
# itemnumber
# 434092      [flavor, warmth, allspice, linger, fading, rye...
# 54866       [rye, mint, spice, spicy, dry, mellow, fairly,...
# 482729      [rye, mint, spice, spicy, dry, mellow, fairly,...
# 246603      [note, syrup, vanilla, nice, unfortunately, pe...
# 321208      [note, syrup, maple, flavour, vanilla, nice, a...
# ['Name: CROWN ROYAL WHISKY']
#
# Price: [30.5] per [750]ml
# Rating: [74.72972973]
# Rating/$/750ml: [2.45015507]
#
# ['Nose: maple rye pancake like syrup bourbon cola smell corn sweetness aroma little alcohol acetone clove gum overwhelm appeal green woodiness banana present grain particular butterscotch overall unique butter cinnamon sugar hard detect peach oatmeal wife thought whisky reminds fragrant cherry ethanol floral juicy lighter earthy especially nose mint high solvent']
#
# ['Taste: rye maple royal canadian whisky butterscotch cinnamon classic mouth juniper definite typical buttercream caraway bold mouthfeel grain like bitterness come cedar subdue feel smooth syrup night end ethanol corn join complexity holy summer cola hint ice nose detect butter wonderful clove sip sticky quickly tip peanut character lingers cherry pith']
#
# ['Finish: butterscotch note linger bitterness cola proof rye vanilla wine caramel unfortunately high spice syrup little maple light thought palate classic honestly gum lingers flat taste easy drinking honey low dark savory quickly heat pepper barrel fade end start whisky stay flavour apple grain bitter fruit herbal butter pretty bit harshness']
#
# ['Name: CROWN ROYAL NORTHERN HARVEST RYE']
#
# Price: [35.95] per [750]ml
# Rating: [77.9047619]
# Rating/$/750ml: [2.16703093]
#
# ['Nose: rye smell spice clove like hint generic aroma nutmeg pie baking detect dill glass banana overwhelm pudding slightly bread especially sugary faint come present sweetness green classic candy bake pear way soft floral cinnamon sugar noticeably additional coke passion berry caraway main dash offensive encounter basil sun melt common particular']
#
# ['Taste: rye canadian whisky like butterscotch high good help clove decent cinnamon ale royal ginger quickly classic wood way definite typical hint different surprising warmth smell drink feel complexity prominent nutmeg spiciness brown present hard come bitter kind lot pleasant sugar concentrate creep abv brash end start viscosity arrival spirity grain']
#
# ['Finish: flavor warmth allspice linger fading rye palate soft note experience wood pepper bitterness sip end throat astringent like quick bit creamy cotton pleasant chewy wrap chocolatey smooth seed subdue gently fruity increase citrusy cookie slight pith fade intensity grainy develops rough non cayenne nice pleasantly custard little character cinnamon grapefruit']
